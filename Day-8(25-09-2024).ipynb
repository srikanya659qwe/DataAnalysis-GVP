# %% [markdown]
# #### Day objectives:
#         - pandas Conti..

# %%
import pandas as pd

# %%
bird=pd.read_csv('bird.csv')
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
titanic=pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Dataset reading:

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
bird.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
bird.columns[3]
# Out:
# 'ulnal'

# %%
bird.columns[8:]
# Out:
# Index(['tibw', 'tarl', 'tarw', 'type'], dtype='object')

# %%
bird.columns[:4]
# Out:
# Index(['id', 'huml', 'humw', 'ulnal'], dtype='object')

# %%
bird['huml']
# Out:
# 0      80.78
# 1      88.91
# 2      79.97
# 3      77.65
# 4      62.80
#        ...
# 415    17.96
# 416    19.21
# 417    18.79
# 418    20.38
# 419    17.89
# Name: huml, Length: 420, dtype: float64

# %%
type(bird['huml'])
# Out:
# pandas.core.series.Series

# %%
bird[['huml']]
# Out:
#       huml
# 0    80.78
# 1    88.91
# 2    79.97
# 3    77.65
# 4    62.80
# ..     ...
# 415  17.96
# 416  19.21
# 417  18.79
# 418  20.38
# 419  17.89
#
# [420 rows x 1 columns]

# %%
type(bird[['huml']])
# Out:
# pandas.core.frame.DataFrame

# %%
bird[['huml','humw']]
# Out:
#       huml  humw
# 0    80.78  6.68
# 1    88.91  6.63
# 2    79.97  6.37
# 3    77.65  5.70
# 4    62.80  4.84
# ..     ...   ...
# 415  17.96  1.63
# 416  19.21  1.64
# 417  18.79  1.63
# 418  20.38  1.78
# 419  17.89  1.44
#
# [420 rows x 2 columns]

# %%
titanic[['Age','Embarked']]
# Out:
#       Age Embarked
# 0    22.0        S
# 1    38.0        C
# 2    26.0        S
# 3    35.0        S
# 4    35.0        S
# ..    ...      ...
# 886  27.0        S
# 887  19.0        S
# 888   NaN        S
# 889  26.0        C
# 890  32.0        Q
#
# [891 rows x 2 columns]

# %% [markdown]
# #### info()

# %%
bird.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      420 non-null    int64
#  1   huml    419 non-null    float64
#  2   humw    419 non-null    float64
#  3   ulnal   417 non-null    float64
#  4   ulnaw   418 non-null    float64
#  5   feml    418 non-null    float64
#  6   femw    419 non-null    float64
#  7   tibl    418 non-null    float64
#  8   tibw    419 non-null    float64
#  9   tarl    419 non-null    float64
#  10  tarw    419 non-null    float64
#  11  type    420 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### Describe():

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### DataSet Indexing
#         - iloc-->integer location---> int index values
#         - loc-->location-->int/non-int index values

# %%
bird.iloc[[100]]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 100  100  67.06  3.54  67.98   3.24  24.82  1.77  51.88  1.86  30.11  1.63
#
#     type
# 100   SW

# %%
bird.loc[[100]]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 100  100  67.06  3.54  67.98   3.24  24.82  1.77  51.88  1.86  30.11  1.63
#
#     type
# 100   SW

# %%
titanic.iloc[[500]]
# Out:
#      PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  \
# 500          501         0       3  Calic, Mr. Petar  male  17.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 500      0  315086  8.6625   NaN        S

# %%
titanic.iloc[500:551]
# Out:
#      PassengerId  Survived  Pclass  \
# 500          501         0       3
# 501          502         0       3
# 502          503         0       3
# 503          504         0       3
# 504          505         1       1
# 505          506         0       1
# 506          507         1       2
# 507          508         1       1
# 508          509         0       3
# 509          510         1       3
# 510          511         1       3
# 511          512         0       3
# 512          513         1       1
# 513          514         1       1
# 514          515         0       3
# 515          516         0       1
# 516          517         1       2
# 517          518         0       3
# 518          519         1       2
# 519          520         0       3
# 520          521         1       1
# 521          522         0       3
# 522          523         0       3
# 523          524         1       1
# 524          525         0       3
# ...

# %%
titanic.loc[500:551]
# Out:
#      PassengerId  Survived  Pclass  \
# 500          501         0       3
# 501          502         0       3
# 502          503         0       3
# 503          504         0       3
# 504          505         1       1
# 505          506         0       1
# 506          507         1       2
# 507          508         1       1
# 508          509         0       3
# 509          510         1       3
# 510          511         1       3
# 511          512         0       3
# 512          513         1       1
# 513          514         1       1
# 514          515         0       3
# 515          516         0       1
# 516          517         1       2
# 517          518         0       3
# 518          519         1       2
# 519          520         0       3
# 520          521         1       1
# 521          522         0       3
# 522          523         0       3
# 523          524         1       1
# 524          525         0       3
# ...

# %%
bird.iloc[250:300]
# Out:
#       id   huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 250  250  99.69  6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23  4.21
# 251  251  34.84  2.44   40.68   2.04  38.43  2.54   42.48  2.45  20.07  3.15
# 252  252  33.12  2.40   39.85   1.80  27.46  2.19   38.99  2.15  19.10  2.89
# 253  253  35.63  2.40   42.67   2.02  28.51  2.41   42.64  2.46  21.05  3.12
# 254  254  29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81  25.22  1.62
# 255  255  30.60  2.45   25.90   1.87  32.36  2.10   50.25  1.88  33.58  1.88
# 256  256  30.25  2.29   25.14   1.87  31.61  2.18   50.98  2.00  33.50  1.93
# 257  257  42.52  2.99   36.73   2.91  52.24  3.81   81.57  3.71  61.27  2.71
# 258  258  45.60  3.35   38.73   3.52  54.45  4.10   83.59  3.72  63.91  2.67
# 259  259  43.97  3.54   38.38   3.14  52.49  4.25   83.15  4.12  61.08  3.04
# 260  260  46.38  3.41   39.80   3.48  54.67  4.08   85.88  4.04  63.75  3.09
# ...

# %% [markdown]
# #### titanic
#         rows--->150--200
#         columns--->passangerid,survived,class

# %%
titanic.iloc[150:201,0:3]
# Out:
#      PassengerId  Survived  Pclass
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
# 156          157         1       3
# 157          158         0       3
# 158          159         0       3
# 159          160         0       3
# 160          161         0       3
# 161          162         1       2
# 162          163         0       3
# 163          164         0       3
# 164          165         0       3
# 165          166         1       3
# 166          167         1       1
# 167          168         0       3
# 168          169         0       1
# 169          170         0       3
# 170          171         0       1
# 171          172         0       3
# 172          173         1       3
# 173          174         0       3
# 174          175         0       1
# 175          176         0       3
# ...

# %%
titanic.loc[150:200,['PassengerId','Survived','Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
# 156          157         1       3
# 157          158         0       3
# 158          159         0       3
# 159          160         0       3
# 160          161         0       3
# 161          162         1       2
# 162          163         0       3
# 163          164         0       3
# 164          165         0       3
# 165          166         1       3
# 166          167         1       1
# 167          168         0       3
# 168          169         0       1
# 169          170         0       3
# 170          171         0       1
# 171          172         0       3
# 172          173         1       3
# 173          174         0       3
# 174          175         0       1
# 175          176         0       3
# ...

# %% [markdown]
# #### bird:
#         - rows-->350-400
#         - columns--->last 4 columns

# %%
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird.iloc[350:401,8:]
# Out:
#      tibw   tarl  tarw type
# 350  2.08  48.35  1.95   SO
# 351  1.96  36.26  1.70   SO
# 352  1.58  30.39  1.34   SO
# 353  2.04  32.85  1.81   SO
# 354  2.07  34.64  1.78   SO
# 355  1.06  22.09  0.78   SO
# 356  1.24  27.46  0.98   SO
# 357  1.47  30.63  1.22   SO
# 358  1.31  29.86  1.04   SO
# 359  1.30  25.03  1.05   SO
# 360  1.33  28.55  1.08   SO
# 361  1.35  30.25  1.09   SO
# 362  1.42  28.62  0.96   SO
# 363  1.40  27.65  1.11   SO
# 364  1.98  33.79  1.61   SO
# 365  1.98  34.60  1.63   SO
# 366  1.08  21.41  0.92   SO
# 367  0.95  15.97  0.75   SO
# 368  0.91  19.10  0.86   SO
# 369  0.88  16.34  0.89   SO
# 370  0.92  17.55  0.88   SO
# 371  0.98  18.15  1.28   SO
# 372  1.00  18.38  0.80   SO
# 373  1.03  18.23  0.73   SO
# 374  0.91  18.15  0.69   SO
# 375  0.88  17.39  0.79   SO
# 376  1.23  17.81  0.69   SO
# 377  0.87  16.97  0.66   SO
# 378   NaN  18.46  0.91   SO
# 379  1.26  17.49  1.02   SO
# 380  1.83  26.66  1.65   SO
# 381  1.13  19.33  1.00   SO
# ...

# %%
bird.loc[350:400,['tibw','tarl','tarw','type']]
# Out:
#      tibw   tarl  tarw type
# 350  2.08  48.35  1.95   SO
# 351  1.96  36.26  1.70   SO
# 352  1.58  30.39  1.34   SO
# 353  2.04  32.85  1.81   SO
# 354  2.07  34.64  1.78   SO
# 355  1.06  22.09  0.78   SO
# 356  1.24  27.46  0.98   SO
# 357  1.47  30.63  1.22   SO
# 358  1.31  29.86  1.04   SO
# 359  1.30  25.03  1.05   SO
# 360  1.33  28.55  1.08   SO
# 361  1.35  30.25  1.09   SO
# 362  1.42  28.62  0.96   SO
# 363  1.40  27.65  1.11   SO
# 364  1.98  33.79  1.61   SO
# 365  1.98  34.60  1.63   SO
# 366  1.08  21.41  0.92   SO
# 367  0.95  15.97  0.75   SO
# 368  0.91  19.10  0.86   SO
# 369  0.88  16.34  0.89   SO
# 370  0.92  17.55  0.88   SO
# 371  0.98  18.15  1.28   SO
# 372  1.00  18.38  0.80   SO
# 373  1.03  18.23  0.73   SO
# 374  0.91  18.15  0.69   SO
# 375  0.88  17.39  0.79   SO
# 376  1.23  17.81  0.69   SO
# 377  0.87  16.97  0.66   SO
# 378   NaN  18.46  0.91   SO
# 379  1.26  17.49  1.02   SO
# 380  1.83  26.66  1.65   SO
# 381  1.13  19.33  1.00   SO
# ...

# %% [markdown]
# #### set_indexing:
#         pd.set_index('column name')

# %%
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
index=bird.set_index('type')
index
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %% [markdown]
# #### reset_indexing:
#         - pd.reset_index()

# %%
reset=index.reset_index()
reset
# Out:
#     type   id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  \
# 0     SW    0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70
# 1     SW    1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50
# 2     SW    2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31
# 3     SW    3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78
# 4     SW    4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88
# ..   ...  ...    ...   ...    ...    ...    ...   ...    ...   ...    ...
# 415   SO  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99
# 416   SO  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60
# 417   SO  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86
# 418   SO  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98
# 419   SO  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69
#
#      tarw
# 0    3.84
# 1    4.01
# 2    3.34
# 3    3.41
# 4    3.13
# ...

# %% [markdown]
# #### Dataset Sorting:
#         - pd.sort_index()--->ascending order
#         - pd.sort_index(ascending=False)descending order
#         - pd.sort_index(ascending=True)
#
# #### column names:
#         - pd.sort_index(axis=1,ascending=True)
#         - pd.sort_index(axis=1,ascending=False)
#
# #### column values:
#         - pd.sort_values(by='column name',ascending=True)

# %%
bird.sort_index()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird.sort_index(ascending=False)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type
# 419   SO
# 418   SO
# 417   SO
# 416   SO
# 415   SO
# ...

# %%
titanic.sort_index(ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
bird.sort_index(ascending=True)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_index(axis=1,ascending=True)
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# ...

# %%
titanic.sort_index(axis=1,ascending=False)
# Out:
#                Ticket  Survived  SibSp     Sex  Pclass  PassengerId  Parch  \
# 0           A/5 21171         0      1    male       3            1      0
# 1            PC 17599         1      1  female       1            2      0
# 2    STON/O2. 3101282         1      0  female       3            3      0
# 3              113803         1      1  female       1            4      0
# 4              373450         0      0    male       3            5      0
# ..                ...       ...    ...     ...     ...          ...    ...
# 886            211536         0      0    male       2          887      0
# 887            112053         1      0  female       1          888      0
# 888        W./C. 6607         0      1  female       3          889      2
# 889            111369         1      0    male       1          890      0
# 890            370376         0      0    male       3          891      0
#
# ...

# %%
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird.sort_index(axis=1,ascending=True)
# Out:
#       feml  femw   huml  humw   id   tarl  tarw   tibl  tibw type  ulnal  \
# 0    41.81  3.70  80.78  6.68    0  38.70  3.84   5.50  4.03   SW  72.01
# 1    47.04  4.30  88.91  6.63    1  41.50  4.01  80.22  4.51   SW  80.53
# 2    43.07  3.90  79.97  6.37    2  38.31  3.34  75.35  4.04   SW  69.26
# 3    40.04  3.52  77.65  5.70    3  35.78  3.41  69.17  3.40   SW  65.76
# 4    33.95  2.72  62.80  4.84    4  31.88  3.13  56.27  2.96   SW  52.09
# ..     ...   ...    ...   ...  ...    ...   ...    ...   ...  ...    ...
# 415  18.36  1.54  17.96  1.63  415  21.99  1.15  31.25  1.33   SO  19.25
# 416  19.24  1.45  19.21  1.64  416  23.60  1.15  33.21  1.28   SO  20.76
# 417  20.96  1.43  18.79  1.63  417  22.86  1.21  34.45  1.41   SO  19.83
# 418  21.35  1.48  20.38  1.78  418  25.98  1.24  36.09  1.53   SO  22.53
# 419  17.62  1.34  17.89  1.44  419  21.69  1.05  29.81  1.24   SO  19.26
#
#      ulnaw
# 0     4.88
# 1     5.59
# 2     5.28
# 3     4.77
# 4     3.73
# ..     ...
# ...

# %%
bird.sort_index(axis=1,ascending=False)
# Out:
#      ulnaw  ulnal type  tibw   tibl  tarw   tarl   id  humw   huml  femw  \
# 0     4.88  72.01   SW  4.03   5.50  3.84  38.70    0  6.68  80.78  3.70
# 1     5.59  80.53   SW  4.51  80.22  4.01  41.50    1  6.63  88.91  4.30
# 2     5.28  69.26   SW  4.04  75.35  3.34  38.31    2  6.37  79.97  3.90
# 3     4.77  65.76   SW  3.40  69.17  3.41  35.78    3  5.70  77.65  3.52
# 4     3.73  52.09   SW  2.96  56.27  3.13  31.88    4  4.84  62.80  2.72
# ..     ...    ...  ...   ...    ...   ...    ...  ...   ...    ...   ...
# 415   1.33  19.25   SO  1.33  31.25  1.15  21.99  415  1.63  17.96  1.54
# 416   1.49  20.76   SO  1.28  33.21  1.15  23.60  416  1.64  19.21  1.45
# 417   1.53  19.83   SO  1.41  34.45  1.21  22.86  417  1.63  18.79  1.43
# 418   1.50  22.53   SO  1.53  36.09  1.24  25.98  418  1.78  20.38  1.48
# 419   1.10  19.26   SO  1.24  29.81  1.05  21.69  419  1.44  17.89  1.34
#
#       feml
# 0    41.81
# 1    47.04
# 2    43.07
# 3    40.04
# 4    33.95
# ..     ...
# ...

# %%
bird.sort_index(axis=0,ascending=False)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type
# 419   SO
# 418   SO
# 417   SO
# 416   SO
# 415   SO
# ...

# %%
titanic.sort_index(axis=0,ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
bird.sort_values(by='huml',ascending=True)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48  1.12   24.91   0.92   17.55
# ..   ...     ...    ...     ...    ...     ...   ...     ...    ...     ...
# 38    38  272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77
# 60    60  300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01
# 56    56  310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13
# 58    58  420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35
# 342  342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94
#
#      tarw type
# 264  1.23    P
# 377  0.66   SO
# ...

# %%
bird.sort_values(by='huml',ascending=False)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 58    58  420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35
# 56    56  310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13
# 60    60  300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01
# 38    38  272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77
# 39    39  270.00  14.25  310.00  10.90   86.20  9.96  125.76   9.63   79.18
# ..   ...     ...    ...     ...    ...     ...   ...     ...    ...     ...
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 342  342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94
#
#       tarw type
# 58    8.93   SW
# 56    7.69   SW
# ...

# %%
titanic.sort_values(by=['Age','Embarked'],ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 644          645         1       3                    Baclini, Miss. Eugenie
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 846          847         0       3                  Sage, Mr. Douglas Bullen
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# #### Dataset Filtering

# %%
bird.shape
# Out:
# (420, 12)

# %%
>90

# %%
bird[bird['huml'] > 90]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 10   6.63   SW
# 11   4.59   SW
# ...

# %%
bird[bird['huml'] > 90].shape
# Out:
# (106, 12)

# %% [markdown]
# >90 < 150

# %%
bird[(bird['huml'] > 90) & (bird['huml'] < 150)]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 13    13  148.91   6.78  121.35   6.50  44.29  6.33  155.00  6.68  73.71
# 14    14  149.19   6.98  121.48   6.21  43.33  5.39  155.00  6.61  75.65
# 15    15  140.59   6.59  115.97   5.81  39.75  5.61  166.00  7.83  74.86
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 13   4.24   SW
# 14   3.36   SW
# ...

# %%
bird[(bird['huml'] > 90) & (bird['huml'] < 150)].shape
# Out:
# (78, 12)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### titanic-->Embarked--->"S" type

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic[titanic['Embarked'] == "S"]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
titanic[titanic['Embarked'] == "S"].shape
# Out:
# (644, 12)

# %% [markdown]
# #### embarked--->S and C

# %%
titanic[(titanic['Embarked'] =="S") | (titanic['Embarked'] == "C")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[(titanic['Embarked'] =="S") | (titanic['Embarked'] == "C")].shape
# Out:
# (812, 12)

# %%
bird.shape
# Out:
# (420, 12)

# %%
bird[(bird['type'] =="SW") | (bird['type'] =="SO")]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird[(bird['type'] =="SW") | (bird['type'] =="SO")].shape
# Out:
# (244, 12)

# %%
bird[(bird['type'] =="P") | (bird['type'] =="T")]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 181  181  43.97  4.64  51.07   3.80  38.76  3.18  55.67  2.88  30.41  2.83
# 182  182  44.58  5.76  52.76   4.84  40.47  3.76  56.42  3.31  31.32  3.34
# 183  183  20.25  2.35  25.14   1.76  20.17  1.37  27.67  1.41  15.68  1.55
# 184  184  48.70  5.46  57.39   3.73  42.56  3.07  52.42  2.85  27.23  3.03
# 185  185  35.74  3.91  39.20   2.93  33.01  2.65  42.80  2.18  24.85  2.34
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 287  287  27.72  2.67  32.00   2.21  22.68  2.13  32.50  1.76  19.65  1.64
# 288  288  29.14  2.75  32.91   2.16  23.13  2.11  33.89  1.80  20.86  1.70
# 289  289  27.85  2.65  32.62   2.05  22.84  2.14  33.62  1.91  20.82  1.80
# 290  290  20.06  1.73  23.15   1.49  16.63  1.57  24.71  1.29  15.19  1.24
# 291  291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
#
#     type
# 181    T
# 182    T
# 183    T
# 184    T
# 185    T
# ...

# %%
bird[(bird['type'] =="P") | (bird['type'] =="T")].shape
# Out:
# (61, 12)

# %%
titanic[titanic['Sex'] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Sex'] == "female"].shape
# Out:
# (314, 12)

# %%
titanic[titanic['Sex'] == "male"]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic[titanic['Sex'] == "male"].shape
# Out:
# (577, 12)
